# %% [markdown]
# # Load github token

# %%
import json

# %%
TOKEN_PATH = '/content/drive/MyDrive/AI/project/git_token.json'

# %%
GIT_TOKEN = json.load(open(TOKEN_PATH))['token']

# %% [markdown]
# # GitHub commands

# %%
# !ls

# %%
# %cd /content/drive/MyDrive/AI/project/CSGY-6613

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	git.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git commit -m 'Ad'
